# %%
import  os

# %%
os.getcwd() #current working directory
# Out:
# 'C:\\Users\\akshaya.srikanth\\Desktop\\Python'

# %%
os.listdir() #all files/folders within the directory
# Out:
# ['.gitignore',
#  '.ipynb_checkpoints',
#  '.vs',
#  'Conditional statements and String Methods.ipynb',
#  'DICTIONARY.ipynb',
#  'Enumerate and Zip ,While Loop,Break and Continue.ipynb',
#  'Lib',
#  'Loops and Range function.ipynb',
#  'Pandas - Q1 Sales.csv',
#  'Pandas_basics.ipynb',
#  'Python Game (Guess the num).ipynb',
#  'Python_basics.ipynb',
#  'pyvenv.cfg',
#  'Scripts',
#  'untitled',
#  'Untitled.ipynb',
#  'Untitled1.ipynb']

# %% [markdown]
# ### change your current directory

# %%
os.chdir(r"C:\\Users\\akshaya.srikanth\\Desktop\\Python\\virtual environment")

# %%
os.getcwd()
# Out:
# 'C:\\Users\\akshaya.srikanth\\Desktop\\Python\\virtual environment'

# %%
print(os.listdir())
# Out:
# ['.gitignore', '.ipynb_checkpoints', '.vs', 'Conditional statements and String Methods.ipynb', 'DICTIONARY.ipynb', 'Enumerate and Zip ,While Loop,Break and Continue.ipynb', 'Lib', 'Loops and Range function.ipynb', 'Pandas - Q1 Sales.csv', 'Pandas_basics.ipynb', 'Python Game (Guess the num).ipynb', 'Python_basics.ipynb', 'pyvenv.cfg', 'Scripts', 'untitled', 'Untitled.ipynb', 'Untitled1.ipynb']

# %% [markdown]
# ## to get the file path

# %%
for root,directory,file in os.walk(os.getcwd()):
       print(root)
# Out:
# C:\Users\akshaya.srikanth\Desktop\Python\virtual environment
# C:\Users\akshaya.srikanth\Desktop\Python\virtual environment\.ipynb_checkpoints
# C:\Users\akshaya.srikanth\Desktop\Python\virtual environment\.vs
# C:\Users\akshaya.srikanth\Desktop\Python\virtual environment\.vs\virtual environment
# C:\Users\akshaya.srikanth\Desktop\Python\virtual environment\.vs\virtual environment\v15
# C:\Users\akshaya.srikanth\Desktop\Python\virtual environment\Lib
# C:\Users\akshaya.srikanth\Desktop\Python\virtual environment\Lib\site-packages
# C:\Users\akshaya.srikanth\Desktop\Python\virtual environment\Lib\site-packages\pip
# C:\Users\akshaya.srikanth\Desktop\Python\virtual environment\Lib\site-packages\pip\_internal
# C:\Users\akshaya.srikanth\Desktop\Python\virtual environment\Lib\site-packages\pip\_internal\cli
# C:\Users\akshaya.srikanth\Desktop\Python\virtual environment\Lib\site-packages\pip\_internal\commands
# ...

# %%
for root,directory,file in os.walk(os.getcwd()):
    if len(directory)>0:
        print(directory)
# Out:
# ['.ipynb_checkpoints', '.vs', 'Lib', 'Scripts']
# ['virtual environment']
# ['v15']
# ['site-packages']
# ['pip', 'pip-21.1.2.dist-info', 'pkg_resources', 'setuptools', 'setuptools-57.0.0.dist-info', 'wheel', 'wheel-0.36.2.dist-info', '_distutils_hack']
# ['_internal', '_vendor']
# ['cli', 'commands', 'distributions', 'index', 'locations', 'metadata', 'models', 'network', 'operations', 'req', 'resolution', 'utils', 'vcs']
# ['build', 'install']
# ['legacy', 'resolvelib']
# ['cachecontrol', 'certifi', 'chardet', 'colorama', 'distlib', 'html5lib', 'idna', 'msgpack', 'packaging', 'pep517', 'pkg_resources', 'progress', 'requests', 'resolvelib', 'tenacity', 'toml', 'urllib3', 'webencodings']
# ['caches']
# ['cli', 'metadata']
# ['_backport']
# ['filters', 'treeadapters', 'treebuilders', 'treewalkers', '_trie']
# ['in_process']
# ['compat']
# ['contrib', 'packages', 'util']
# ['_securetransport']
# ['backports', 'ssl_match_hostname']
# ['extern', 'tests', '_vendor']
# ['data']
# ...

# %%
for root,directory,file in os.walk(os.getcwd()):
    print(file)
# Out:
# ['.gitignore', 'Conditional statements and String Methods.ipynb', 'DICTIONARY.ipynb', 'Enumerate and Zip ,While Loop,Break and Continue.ipynb', 'Loops and Range function.ipynb', 'Pandas - Q1 Sales.csv', 'Pandas_basics.ipynb', 'Python Game (Guess the num).ipynb', 'Python_basics.ipynb', 'pyvenv.cfg', 'untitled', 'Untitled.ipynb', 'Untitled1.ipynb']
# ['Conditional statements and String Methods-checkpoint.ipynb', 'DICTIONARY-checkpoint.ipynb', 'Enumerate and Zip ,While Loop,Break and Continue-checkpoint.ipynb', 'Loops and Range function-checkpoint.ipynb', 'Pandas_basics-checkpoint.ipynb', 'Python Game (Guess the num)-checkpoint.ipynb', 'Python_basics-checkpoint.ipynb', 'Untitled-checkpoint.ipynb', 'Untitled1-checkpoint.ipynb']
# ['slnx.sqlite', 'VSWorkspaceState.json']
# []
# ['.suo']
# []
# ['distutils-precedence.pth', 'pip-21.1.2.virtualenv', 'setuptools-57.0.0.virtualenv', 'wheel-0.36.2.virtualenv', '_virtualenv.pth', '_virtualenv.py']
# ['py.typed', '__init__.py', '__main__.py']
# ...

# %%
for root,directory,file in os.walk(os.getcwd()):
    for f in file:
        print(root+""+f)
# Out:
# C:\Users\akshaya.srikanth\Desktop\Python\virtual environment.gitignore
# C:\Users\akshaya.srikanth\Desktop\Python\virtual environmentConditional statements and String Methods.ipynb
# C:\Users\akshaya.srikanth\Desktop\Python\virtual environmentDICTIONARY.ipynb
# C:\Users\akshaya.srikanth\Desktop\Python\virtual environmentEnumerate and Zip ,While Loop,Break and Continue.ipynb
# C:\Users\akshaya.srikanth\Desktop\Python\virtual environmentLoops and Range function.ipynb
# C:\Users\akshaya.srikanth\Desktop\Python\virtual environmentOS Module.ipynb
# C:\Users\akshaya.srikanth\Desktop\Python\virtual environmentPandas - Q1 Sales.csv
# C:\Users\akshaya.srikanth\Desktop\Python\virtual environmentPandas_basics.ipynb
# C:\Users\akshaya.srikanth\Desktop\Python\virtual environmentPython Game (Guess the num).ipynb
# C:\Users\akshaya.srikanth\Desktop\Python\virtual environmentPython_basics.ipynb
# C:\Users\akshaya.srikanth\Desktop\Python\virtual environmentpyvenv.cfg
# ...

# %%
os.mkdir("PythonCode")# create a folder

# %%
os.rmdir("PythonCode") # remove file if empty else will throw an exception
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# C:\Users\AKSHAY~1.SRI\AppData\Local\Temp/ipykernel_9012/2177996084.py in <module>
# ----> 1 os.rmdir("PythonCode")
#
# OSError: [WinError 145] The directory is not empty: 'PythonCode'

# %% [markdown]
# ## To delete a folder with contents

# %%
import shutil as sh

# %%
pth=r"C:\Users\akshaya.srikanth\Desktop\Python\virtual environment\PythonCode"

# %%
sh.rmtree(pth)

# %%
#To create directory with sub directory

# %%
os.makedirs("A/B/C/D")

# %%
os.getcwd()
# Out:
# 'C:\\Users\\akshaya.srikanth\\Desktop\\Python\\virtual environment'

# %%
os.removedirs("A/B/C/D")

# %%
os.listdir()
# Out:
# ['.gitignore',
#  '.ipynb_checkpoints',
#  '.vs',
#  'Conditional statements and String Methods.ipynb',
#  'DICTIONARY.ipynb',
#  'Enumerate and Zip ,While Loop,Break and Continue.ipynb',
#  'Lib',
#  'Loops and Range function.ipynb',
#  'OS Module.ipynb',
#  'Pandas - Q1 Sales.csv',
#  'Pandas_basics.ipynb',
#  'Python Game (Guess the num).ipynb',
#  'Python_basics.ipynb',
#  'pyvenv.cfg',
#  'Scripts',
#  'Untitled.ipynb']

# %%
os.rename("Pandas - Q1 Sales.csv",'Pandas - Quater_1 Sales.csv')

# %%
#To check the file size or rename files

os.stat('Pandas - Quater_1 Sales.csv').st_size # IN Bytes
# Out:
# 1013

# %%
os.stat('Pandas - Quater_1 Sales.csv').st_size/pow(1024,2) ##IN MB
# Out:
# 0.0009660720825195312

# %%
# To get desktop folder path

os.environ["UserProfile"] +"\Desktop"
# Out:
# 'C:\\Users\\akshaya.srikanth\\Desktop'

# %%
os.path.join(os.path.join(os.environ["UserProfile"],"Desktop"))
# Out:
# 'C:\\Users\\akshaya.srikanth\\Desktop'

# %%
os.path.normpath(os.path.expanduser("~/Desktop"))
# Out:
# 'C:\\Users\\akshaya.srikanth\\Desktop'
